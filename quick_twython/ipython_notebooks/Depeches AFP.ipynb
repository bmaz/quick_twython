# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# %%time
from depechesAFP import *
from scipy import sparse
import numpy as np
# Out:
# CPU times: user 260 ms, sys: 12 ms, total: 272 ms
# Wall time: 271 ms

# %%
def vocabulary():
    filename = "/home/bmazoyer/Documents/TwitterSea/vocabulary.json"
    stream = open(filename,"r+",encoding='utf-8')
    vocabulary = json.load(stream)
    stream.close()
    return vocabulary

# %%
def tfIdfMatrix(words, events):
    """shape a tf_idf matrix out of tweets belonging to each event.
    Return the matrix and a vocabulary of form {"word": index_in_matrix}
    :param words: "text" or "hashtags" --> analyze all words or only hashtags
    :param events: a list of ids. Ex: ['afp.com-20160922T065447Z-TX-PAR-HKZ50']
    """
    
    ref_dict = {
        'hashtags': hashtagsMatrix,
        'text': textMatrix
    }
    
    voc, X = ref_dict[words](events)
    
    transformer = feature_extraction.text.TfidfTransformer()
    tf_idf = transformer.fit_transform(X)
    
    return voc, tf_idf

# %%
# %%time
def hashtagsMatrix(events):
    """shape a scipy.sparse count matrix out of hashtags refering to each event.
    Return the matrix and a vocabulary of form {"word": index_in_matrix}
    :param events: a list of ids. Ex: ['afp.com-20160922T065447Z-TX-PAR-HKZ50']"""
    
    hashtags = [{n['key']: n['doc_count'] for n in getFields(event, "hashtags")} for event in events]
     # hashtags = [{"Sarkozy":2, "Buisson":3}, {"Hollande":4, "Sarkozy":1, "HollandeDehors":5}]
    
    voc = {}
    for doc in hashtags:
        for m in doc:
            if m not in voc:
                voc[m] = len(voc)
    #voc = {"Sarkozy":0, "Buisson":1, "Hollande":2, "HollandeDehors":3}
    
    X = sparse.lil_matrix((len(hashtags),len(voc)), dtype=int)
    for i, doc in enumerate(hashtags):
        X[i, [voc[m] for m in doc]] += np.array(list(doc.values()))
    
   
    return voc, X
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 4.53 µs

# %%
def textMatrix(events):
    """shape a scipy.sparse count matrix out of words (1 to 3-grams) refering to each event.
    Return the matrix and a vocabulary of form {"word": index_in_matrix}
    :param events: a list of ids. Ex: ['afp.com-20160922T065447Z-TX-PAR-HKZ50']"""
    texts = [getText(event) for event in events]
    events_size = [len(texts[i]) for i in range(len(texts))]
    collection = (
        re.sub(
            r'https?\S+|@\S+', '',tweet['first-hit']['hits']['hits'][0]['_source']['text']
        ) for n in texts for tweet in n
    )
    doc_counts = sparse.diags([tweet['doc_count'] for n in texts for tweet in n], dtype=int)
    vectorizer = feature_extraction.text.CountVectorizer(
        stop_words = stopwords,
        min_df = 2,
        ngram_range = (1,1),
        binary = True
    )
#     doc_counts*CountVectorizer = total frequency of words including retweets
    X = doc_counts.dot(vectorizer.fit_transform(collection))
    
#     build matrix with an event on each row.
    row = []
    for i in range(len(events)):
        row.extend([i for n in range(events_size[i])])
    col = range(X.shape[0])
    dat = [1 for n in range(X.shape[0])]
    S = sparse.csr_matrix((dat, (row, col)), shape=(len(events), X.shape[0]))
    
    return vectorizer.get_feature_names() , S*X

# %%
events = filterEvents("20161002", 0)

# %%
vocab, X = textMatrix(events)

# %%
print(X.shape)
# Out:
# (115, 4447)

# %%
from __future__ import division, print_function

import numpy as np
import lda

model = lda.LDA(n_topics=X.shape[0], n_iter=15, random_state=1)
model.fit(X)

# %%
topic_word = model.topic_word_
doc_topic = model.doc_topic_

# %%
n = 5
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(
    topic_most_pr = doc_topic[i].argmax()
    topic_words = np.array(vocab)[np.argsort(topic_word[topic_most_pr])][:-(n+1):-1]
    print("doc: {} topic: {}\n{}\n{}".format(i,
                                            topic_most_pr,
                                            getEventsDetails(events[i])["events.text"][0],
                                            ' '.join(topic_words)))
    print([n['key'] for n in getFields(events[i],"tags")])
    print("")doc: 0
# Out:
# doc: 0 topic: 78
# Hongrie urnes referendum anti refugies Premier ministre Orban
# hongrie référendum orban viktor premier échec sommes fiers quotas
# ['Hongrie Orban', 'Hongrie urnes referendum anti refugies Premier ministre Orban', 'Hongrie revers electoral referendum Orban invalide abstention', 'Hongrie urnes referendum antirefugies Premier ministre Orban', 'Hongrie revers referendum antimigrants Orban invalide abstention']
#
# doc: 1 topic: 78
# Hongrie urnes referendum anti refugies Premier ministre Orban
# hongrie référendum orban viktor premier échec sommes fiers quotas
# ['Hongrie Orban', 'Hongrie urnes referendum anti refugies Premier ministre Orban', 'Hongrie revers electoral referendum Orban invalide abstention', 'Hongrie urnes referendum antirefugies Premier ministre Orban', 'Hongrie revers referendum antimigrants Orban invalide abstention']
#
# doc: 2 topic: 78
# Hongrie urnes referendum anti refugies Premier ministre Orban
# hongrie référendum orban viktor premier échec sommes fiers quotas
# ['Hongrie Orban', 'Hongrie urnes referendum anti refugies Premier ministre Orban', 'Hongrie revers electoral referendum Orban invalide abstention', 'Hongrie urnes referendum antirefugies Premier ministre Orban', 'Hongrie revers referendum antimigrants Orban invalide abstention']
#
# doc: 3 topic: 75
# Jean Marie Pen affronte FN tribunal contester exclusion
# pen jean marie sarkozy fn marine marise tribunal nicolas
# ['Marie Pen', 'Marie Marine Pen Sarkozy', 'Jean Marie Pen Sarkozy occupe terrain Marine Pen evacue']
#
# doc: 4 topic: 40
# Inde ratifie accord climat
# climat inde ratifié mondial troisième pollueur ratifie émetteur effet
# ['Inde ratifie accord climat', 'Inde ratifie dimanche accord climat', 'Inde ratifie accord climat proche entree vigueur']
#
# doc: 5 topic: 38
# pape accuse manuels scolaires propager theorie genre
# manuels scolaires français propager accuse genre pape théorie françois
# ['pape accuse manuels scolaires propager theorie genre']
#
# doc: 6 topic: 102
# Aix Provence proces fictif reclamer nouveau palais justice
# aix provence grande procès réclamer parodie instance 10 19
# ['Aix Provence']
#
# doc: 7 topic: 110
# Policier tue Magnanville juin jihadiste inhume Maroc avocat
# maroc magnanville inhumé été enterré islam rien voir policiers
# ['Magnanville Maroc']
#
# doc: 8 topic: 43
# Libye 10 jihadistes tues Syrte gouvernement
# journaliste tué libye néerlandais combats presse été enlevé ans
# ['Libye Syrte', 'Libye combats meurtriers Syrte journaliste neerlandais tue', 'Libye journaliste neerlandais tue couvrant combats Syrte source medicale', 'Libye 18 morts combats Syrte entre loyalistes EI']
#
# doc: 9 topic: 43
# Libye 10 jihadistes tues Syrte gouvernement
# journaliste tué libye néerlandais combats presse été enlevé ans
#
# doc: 26 topic: 25
# Syrie attentat suicide Hama morts medias officiels
# hama syrie suicide attentat morts assad ville perpétré lundi
# ['Hama Syrie', 'Syrie attentat suicide Hama morts medias officiels', 'Alep Syrie', 'Alep Damas', 'Syrie EI revendique attentats suicide Hama']
#
# doc: 27 topic: 25
# Syrie attentat suicide Hama morts medias officiels
# hama syrie suicide attentat morts assad ville perpétré lundi
# ['Hama Syrie', 'Syrie attentat suicide Hama morts medias officiels', 'Alep Syrie', 'Alep Damas', 'Syrie EI revendique attentats suicide Hama']
#
# doc: 28 topic: 103
# controles facies devant Cour cassation
# faciès contrôles devant cassation cour demain opposant enjeux discriminations
# ['controles facies devant Cour cassation']
#
# doc: 29 topic: 99
# Burkina 3000 personnes se rassemblent hommage Thomas Sankara
# sankara burkina thomas faso mémorial inaugure réhabilitation renaissance lancement
# ['Burkina Sankara Thomas']
#
# doc: 30 topic: 24
# Inde evacue villages frontiere Pakistan
# inde pakistan pigeon entrée nucléaires face vendre parc attaques
# ['Inde Pakistan', 'Cachemire Inde', 'Cachemire Pakistan', 'Cachemire Inde Pakistan', 'poste frontiere familles inquietes tensions Inde Pakistan']
#
# doc: 31 topic: 96
# Turquie policier tue apres tirs roquettes provenance Syrie
# turquie syrie irak prolonge mandat plus turcs militaire voisins
# ['Syrie Turquie', 'Irak Syrie Turquie', 'Turquie Parlement prolonge an mandat militaires turcs Irak Syrie', 'urquie policier tue apres tirs roquettes provenance Syrie']
#
# doc: 32 topic: 96
# Syrie 21 rebelles soutenus Turquie tues mines EI OSDH
# turquie syrie irak prolonge mandat plus turcs militaire voisins
# ['Syrie Turquie', 'Irak Syrie Turquie', 'Turquie Parlement prolonge an mandat militaires turcs Irak Syrie', 'urquie policier tue apres tirs roquettes provenance Syrie', 'Alep Syrie']
#
# doc: 33 topic: 37
# histoire tragique sauvetage bebe Syrie
# syrie histoire bébé sauvetage tragique exacerbées décombres populaire secouriste
# ['histoire tragique sauvetage bebe Syrie']
#
# doc: 34 topic: 55
# Colombie vote Non accord paix Farc
# paix accord non farc colombie voté vote dépouillés ratifier
# ['Colombie vote Non accord paix Farc']
#
# doc: 35 topic: 89
# Theorie genre Vallaud Belkacem regrette parole legere infondee pape
# parole regrette belkacem infondée légère vallaud genre non propos
# ['Theorie genre Vallaud Belkacem regrette parole legere infondee pape']
#
# doc: 36 topic: 83
# Bresil debacle gauche Lula 1er tour municipales
# brésil municipales lula débâcle tour parti travailleurs premier rousseff
# ['Bresil Lula', 'Bresil debacle gauche Lula 1er tour municipales', 'Bresil Municipales PT Lula perd Sao Paulo pleine debacle electorale']
#
# doc: 37 topic: 28
# Cristiano Ronaldo inaugure Lisbonne deuxieme hotel enseigne
# hôtel lisbonne ronaldo cristiano face après match envolera afin
# ['Cristiano Lisbonne Ronaldo', 'Cristiano Ronaldo inaugure Lisbonne deuxieme hotel enseigne']
#
# doc: 38 topic: 99
# Burkina 29 ans apres mort Sankara fascine toujours
# sankara burkina thomas faso mémorial inaugure réhabilitation renaissance lancement
# ['Burkina Sankara', 'Burkina 29 ans apres mort Sankara fascine toujours']
#
# doc: 39 topic: 83
# Bresil debacle gauche Lula 1er tour municipales
# brésil municipales lula débâcle tour parti travailleurs premier rousseff
# ['Bresil Lula', 'Bresil debacle gauche Lula 1er tour municipales', 'Bresil Municipales PT Lula perd Sao Paulo pleine debacle electorale']
#
# doc: 40 topic: 11
# pape accelere procedure vue beatification pere Hamel
# père hamel béatification pape procédure accélère vue accélérer macron
# ['pape accelere procedure vue beatification pere Hamel']
#
# doc: 41 topic: 62
# Ouverture prix Bayeux Calvados correspondants guerre
# bayeux frère accusé fethullah gülen fomenté putsch arrestation turquie
# ['Bayeux Calvados']
#
# doc: 42 topic: 59
# Donald Trump defensive cause feuille impot
# trump impôt cause feuille donald défensive façon génie unis
# ['Donald Trump defensive cause feuille impot']
#
# doc: 43 topic: 54
# Colombie vote accord paix guerilla Farc
# colombie farc guérilla paix vote 79 52 99 ans
# ['Colombie vote accord paix guerilla Farc']
#
# doc: 44 topic: 94
# eglise Saint Etienne Rouvray retrouve fideles deux mois apres attentat
# mois deux attentat église rouvray saint après etienne retrouve
# ['eglise Saint Etienne Rouvray retrouve fideles deux mois apres attentat']
#
# doc: 45 topic: 87
# Debut referendum Colombie paix conclue guerilla Farc
# paix colombie farc ans non colombiens rejet référendum guérilla
# ['Debut referendum Colombie paix conclue guerilla Farc', 'Colombie Santos', 'Colombie dit Non paix Farc Santos se rend']
#
# doc: 46 topic: 48
# pape reveille polemique theorie genre
# pape théorie genre gt accusé communauté noire plaies panser
# ['pape reveille polemique theorie genre']
#
# doc: 47 topic: 94
# Saint Etienne Rouvray eglise rouvre portes deux mois apres attentat
# mois deux attentat église rouvray saint après etienne retrouve
# ['Saint Etienne Rouvray eglise rouvre portes deux mois apres attentat']
#
# doc: 48 topic: 33
# Interdiction Namibie Zimbabwe vendre ivoire etranger
# ivoire zimbabwe namibie vendre trois étranger tués interdiction enfants
# ['Interdiction Namibie Zimbabwe vendre ivoire etranger', 'Namibie Zimbabwe']
#
# doc: 49 topic: 79
# Arnaud Montebourg annonce participation primaire initiee PS
# primaire ps montebourg annonce se arnaud initiée participation legrandjury
# ['Arnaud Montebourg annonce participation primaire initiee PS']
#
# doc: 50 topic: 114
# medecine ouvre saison prix Nobel
# ouvre saison rencontre lundi prix 10 monde colomb colombie
# ['medecine ouvre saison prix Nobel']
#
# doc: 51 topic: 15
# Jordanie defend accord gaz controverse Israel
# jordanie accord gaz entre importation amp signé volé palestinien
# ['Israel Jordanie', 'Jordanie defend accord gaz controverse Israel']
#
# doc: 52 topic: 11
# pape accepte raccourcir delai beatification pere Hamel Vatican
# père hamel béatification pape procédure accélère vue accélérer macron
# ['Hamel Vatican', 'pape accepte raccourcir delai beatification pere Hamel Vatican']
#
# doc: 53 topic: 109
# Valls sonne mobilisation faveur vrai faux candidat Hollande
# valls vrai hollande candidat faveur sonne mobilisation point fn
# ['Valls sonne mobilisation faveur vrai faux candidat Hollande']
#
# doc: 54 topic: 0
# Brexit Londres lancera procedure divorce fin mars
# fin mars londres brexit procédure lancera divorce processus ue
# ['Brexit Londres lancera procedure divorce fin mars', 'Brexit May annonce activation article 50 fin mars ']
#
# doc: 55 topic: 0
# Brexit Londres lancera procedure divorce fin mars
# fin mars londres brexit procédure lancera divorce processus ue
# ['Brexit Londres lancera procedure divorce fin mars', 'Brexit May annonce activation article 50 fin mars ']
#
# doc: 56 topic: 49
# Guadeloupe mineur tue balle
# aixenprovence lieu tribunal mineur balle guadeloupe tué etl 99
# ['Guadeloupe mineur tue balle']
#
# doc: 57 topic: 31
# Hayange Valls revele vrai visage repond Marine Pen FN
# hayange manuel japon marine visage réplique syria via emploi
# ['Hayange Pen Valls', 'Hayange Valls revele vrai visage repond Marine Pen FN']
#
# doc: 58 topic: 91
# Departementale partielle canton Orange deux partis extreme droite second tour
# avait plus tour partis second départementale partielle extrême canton
# ['Departementale partielle canton Orange deux partis extreme droite second tour']
#
# doc: 59 topic: 22
# Sciences Po lance ecole management innovation
# fidèles management protéger exceptionnelle école sciences po innovation via
# ['Sciences Po lance ecole management innovation']
#
# doc: 60 topic: 82
# decolonisation Polynesie discussion mardi ONU
# onu discussion décolonisation polynésie mardi années dix encourager ménagères
# ['decolonisation Polynesie discussion mardi ONU']
#
# doc: 61 topic: 40
# Inde ratifie dimanche accord climat
# climat inde ratifié mondial troisième pollueur ratifie émetteur effet
# ['Inde ratifie accord climat', 'Inde ratifie dimanche accord climat']
#
# doc: 62 topic: 0
# Royaume Uni enclenchera processus sortie UE fin mars May
# fin mars londres brexit procédure lancera divorce processus ue
# ['Royaume Uni enclenchera processus sortie UE fin mars May', 'Brexit May annonce activation article 50 fin mars ']
#
# doc: 63 topic: 62
# Turquie arrestation frere Fethullah Gulen accuse fomente putsch avorte
# bayeux frère accusé fethullah gülen fomenté putsch arrestation turquie
# ['urquie arrestation frere Fethullah Gulen accuse fomente putsch avorte']
#
# doc: 64 topic: 42
# Gironde Allemande se noie ocean Lacanau
# enfer terre devenue pousse alep lacanau se noie gironde
# ['Gironde Lacanau', 'Gironde Allemande se noie ocean Lacanau']
#
# doc: 65 topic: 106
# Sarkozy promet budget 3 deficit 2019 equilibre 2022
# 29 fascine conditions toujours après mort déficit 2022 équilibre
# ['Sarkozy promet budget 3 deficit 2019 equilibre ']
#
# doc: 66 topic: 86
# Nouvelle Caledonie veut proteger exceptionnelle diversite palmiers
# veut diversité palmiers nouvelle calédonie smart 37 symbolique référendum
# ['Nouvelle Caledonie veut proteger exceptionnelle diversite palmiers']
#
# doc: 67 topic: 76
# UE lance initiative humanitaire urgence Alep
# humanitaire alep urgence militaires viennent ht rafales ue dit
# ['UE lance initiative humanitaire urgence Alep', 'Alep Syrie']
#
# doc: 68 topic: 55
# Colombie refuse ratifier paix Farc
# paix accord non farc colombie voté vote dépouillés ratifier
# ['Colombie refuse ratifier paix Farc']
#
# doc: 69 topic: 67
# Irlande chenil Europe royaume trafiquants chiens
# irlande victoire tente hillary clinton nouvelle arc défaite 21
# ['Europe Irlande', 'Irlande Nord', 'Irlande chenil Europe royaume trafiquants chiens']
#
# doc: 70 topic: 14
# Bosnie municipales candidat serbe proclame victoire Srebrenica
# polémique bosnie srebrenica périodes clés cinq mairie candidat ans
# ['Srebrenica serbe', 'Bosnie Serbe portes mairie Srebrenica']
#
# doc: 71 topic: 51
# IVG rassemblement contre projet interdiction Pologne
# ivg contre interdiction polonaises grève totale quasi massivement pologne
# ['IVG rassemblement contre projet interdiction Pologne']
#
# doc: 72 topic: 33
# Drame route Moselle mere trois enfants tues pere grievement blesse
# ivoire zimbabwe namibie vendre trois étranger tués interdiction enfants
# ['Drame route Moselle mere trois enfants tues pere grievement blesse']
#
# doc: 73 topic: 47
# Nobel medecine laureats dix dernieres annees
# kardashian dernières lauréats quitté nord antisémitisme europe inquiète américaine
# ['Nobel medecine laureats dix dernieres annees']
#
# doc: 74 topic: 20
# Apres Kunduz MSF denonce multiplication agressions contre hopitaux
# française contre morts après rassemblement an hôpitaux dénonce agressions
# ['Apres Kunduz MSF denonce multiplication agressions contre hopitaux']
#
# doc: 75 topic: 86
# apres referendum symbolique Smart passe 39 heures
# veut diversité palmiers nouvelle calédonie smart 37 symbolique référendum
# ['apres referendum symbolique Smart passe 39 heures']
#
# doc: 76 topic: 52
# commerce controverse ivoire nouveau sellette Johannesburg
# calvados police commerce kim lundi matin été nouveau braquage
# ['commerce controverse ivoire nouveau sellette Johannesburg']
#
# doc: 77 topic: 100
# Afghanistan offensive talibane veille rendez donateurs
# faux veille donateurs rendez offensive dimanche paulo français directlnc
# ['Afghanistan offensive talibane veille rendez donateurs', 'Afghanistan Kunduz', 'Afghanistan offensive talibane Kunduz veille rendez donateurs']
#
# doc: 78 topic: 57
# Inde dalits se revoltent carcasses vaches pourrissent
# soirée photographe se décédé reportage the musique partir révoltent
# ['Inde dalits se revoltent carcasses vaches pourrissent']
#
# doc: 79 topic: 36
# Mexique 400 personnes evacuees apres eruption volcan
# personnes après mexique 400 évacuées éruption volcan fuego europe1
# ['Mexique 400 personnes evacuees apres eruption volcan']
#
# doc: 80 topic: 12
# Ethiopie 52 morts mouvement foule lors festival gouvernement regional
# devenu toussa 300km vents pense menacés vraiment reclassé 2007
# ['Ethiopie 52 morts mouvement foule lors festival gouvernement regional']
#
# doc: 81 topic: 29
# Hayange vrai visage anti populaire Front national selon Valls
# national front trois egypte arrêtés droite combat quatrième via
# ['Hayange Valls', 'Hayange vrai visage anti populaire Front national selon Valls']
#
# doc: 82 topic: 67
# Victoire historique Irlande nouvelle defaite Japon Arc
# irlande victoire tente hillary clinton nouvelle arc défaite 21
# ['Irlande Japon', 'Victoire historique Irlande nouvelle defaite Japon Arc']
#
# doc: 83 topic: 66
# Little Syria quartier oublie Manhattan revient vie
# gt évacuations puissant vie quartier manhattan approche base frappe
# ['Little Syria quartier oublie Manhattan revient vie']
#
# doc: 84 topic: 79
# Valls Macron se trompe qu
# primaire ps montebourg annonce se arnaud initiée participation legrandjury
# ['Valls Macron se trompe qu']
#
# doc: 85 topic: 52
# Kim Kardashian quitte lundi matin apres entendue
# calvados police commerce kim lundi matin été nouveau braquage
# ['Kim Kardashian quitte lundi matin apres entendue', 'Kanye West']
#
# doc: 86 topic: 79
# PS accorde conditions primaire 22 29 janvier
# primaire ps montebourg annonce se arnaud initiée participation legrandjury
# ['PS accorde conditions primaire 22 29 janvier', 'PS accorde conditions primaire Montebourg se lance']
#
# doc: 87 topic: 87
# Colombie incertitude apres rejet accord paix Farc
# paix colombie farc ans non colombiens rejet référendum guérilla
# ['Colombie incertitude apres rejet accord Farc', 'Colombie incertitude apres rejet accord paix Farc']
#
# doc: 88 topic: 107
# Kardashian agressee acte rare remet cause securite Hidalgo
# sécurité remet moi rare hidalgo répond tou ouvre selon
# ['Kardashian agressee acte rare remet cause securite Hidalgo']
#
# doc: 89 topic: 33
# Interdiction Namibie Zimbabwe vendre ivoire etranger
# ivoire zimbabwe namibie vendre trois étranger tués interdiction enfants
# ['Namibie Zimbabwe', 'Namibie Zimbabwe pourront vendre stock ivoire']
#
# doc: 90 topic: 79
# PS accorde conditions primaire Montebourg se lance
# primaire ps montebourg annonce se arnaud initiée participation legrandjury
# ['PS accorde conditions primaire Montebourg se lance', 'PS accorde conditions primaire 22 29 janvier']
#
# doc: 91 topic: 42
# Syrie tirs artillerie lourde Alep regime progresse
# enfer terre devenue pousse alep lacanau se noie gironde
# ['regime syrien pousse Alep devenue enfer Terre', 'Alep Syrie']
#
# doc: 92 topic: 96
# plus gros vols bijoux particuliers
# turquie syrie irak prolonge mandat plus turcs militaire voisins
# ['plus gros vols bijoux particuliers']
#
# doc: 93 topic: 42
# Syrie principal hopital Alep bombarde regime toujours offensive
# enfer terre devenue pousse alep lacanau se noie gironde
# ['regime syrien pousse Alep devenue enfer Terre', 'Alep Syrie']
#
# doc: 94 topic: 92
# Kim Kardashian agressee main armee hotel indemne
# droite kardashian deux kim agressée judiciaire euros acte très
# ['Kim Kardashian agressee main armee hotel indemne']
#
# doc: 95 topic: 33
# Trois heures suspendus grande roue Londres
# ivoire zimbabwe namibie vendre trois étranger tués interdiction enfants
# ['rois heures suspendus grande roue Londres']
#
# doc: 96 topic: 73
# Egypte trois journalistes arretes apres micro trottoirs
# journalistes micro trottoirs ferme sociaux tendance minutebuzz interdits pourront
# ['Egypte trois journalistes arretes apres micro trottoirs']
#
# doc: 97 topic: 14
# cinq periodes cles guerilla Farc Colombie
# polémique bosnie srebrenica périodes clés cinq mairie candidat ans
# ['cinq periodes cles guerilla Farc Colombie']
#
# doc: 98 topic: 10
# Haiti inegalites exacerbees face menace ouragan Matthew
# matthew haïti jamaïque ouragan cuba menace bahamas destructeur catégorie
# ['Haiti inegalites exacerbees face menace ouragan Matthew']
#
# doc: 99 topic: 5
# Marianne Faithfull novembre Bataclan sert rien peur
# rien in hui novembre bataclan marianne faithfull peur photographique
# ['Marianne Faithfull novembre Bataclan sert rien peur']
#
# doc: 100 topic: 31
# Primaire gauche mode emploi
# hayange manuel japon marine visage réplique syria via emploi
# ['Primaire gauche mode emploi']
#
# doc: 101 topic: 48
# Hillary Clinton tente panser plaies communaute noire
# pape théorie genre gt accusé communauté noire plaies panser
# ['Hillary Clinton tente panser plaies communaute noire']
#
# doc: 102 topic: 92
# Kim Kardashian braquee bijoux voles plusieurs millions euros
# droite kardashian deux kim agressée judiciaire euros acte très
# ['Kim Kardashian braquee bijoux voles plusieurs millions euros']
#
# doc: 103 topic: 42
# 25 megots ramasses 1h30 pres bassin Villette
# enfer terre devenue pousse alep lacanau se noie gironde
# ['25 megots ramasses 1h30 pres bassin Villette']
#
# doc: 104 topic: 77
# Ethiopie deuil national trois jours apres mort 52 personnes festival
# orange festival gt gouvernement régional 52 hispaniola jours actufr
# ['Ethiopie deuil national trois jours apres mort 52 personnes festival']
#
# doc: 105 topic: 54
# Colombie se prononce paix guerilla Farc
# colombie farc guérilla paix vote 79 52 99 ans
# ['Colombie se prononce paix guerilla Farc']
#
# doc: 106 topic: 30
# Accord processus ratification
# où point revendique parti feu basculé ratification reuters pourtant
# ['Accord processus ratification']
#
# doc: 107 topic: 26
# Japon gouverneurs enceintes encourager hommes participer corvees menageres
# abballa djihadiste ht carré av françaises participer gouverneurs hommes
# ['Japon gouverneurs enceintes encourager hommes participer corvees menageres']
#
# doc: 108 topic: 63
# MinuteBuzz ferme site devient 100 reseaux sociaux tendance fond
# se sert 100 réseaux devient fond va produire via
# ['MinuteBuzz ferme site devient 100 reseaux sociaux tendance fond']
#
# doc: 109 topic: 31
# Meurtre Nemtsov premiere audience publique proces Moscou
# hayange manuel japon marine visage réplique syria via emploi
# ['Moscou Nemtsov']
#
# doc: 110 topic: 40
# Inde ratifie accord climat
# climat inde ratifié mondial troisième pollueur ratifie émetteur effet
# ['Inde ratifie accord climat', 'Inde ratifie accord climat proche entree vigueur']
#
# doc: 111 topic: 108
# Berlin insiste renvoi Grece demandeurs asile
# armée qu forces cette berlin news renvoi exposée asile
# ['Berlin Grece', 'Berlin insiste renvoi Grece demandeurs asile']
#
# doc: 112 topic: 89
# Colombie pays reste divise face paix
# parole regrette belkacem infondée légère vallaud genre non propos
# ['Colombie pays reste divise face paix']
#
# doc: 113 topic: 52
# Braquage Kim Kardashian police assure mettre oeuvre elucider affaire
# calvados police commerce kim lundi matin été nouveau braquage
# ['Braquage Kim Kardashian police assure mettre oeuvre elucider affaire']
#
# doc: 114 topic: 112
# age pierre mines rebelle Ukraine
# après portes 25 près rebelle mines pierre âge eglise
# ['age pierre mines rebelle Ukraine']

# %%
# Out:
# ['Hongrie Orban', 'Hongrie urnes referendum anti refugies Premier ministre Orban', 'Hongrie revers electoral referendum Orban invalide abstention', 'Hongrie urnes referendum antirefugies Premier ministre Orban', 'Hongrie revers referendum antimigrants Orban invalide abstention']
