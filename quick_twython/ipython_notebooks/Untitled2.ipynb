# %%
run depechesAFP.py
# Out:
# key : 0
# Start searching for query Catstrophes naturelles Haiti tete pays comptabilisant plus morts ONU
# Over: attempts:  1 remaining:  179
# key : 0
# Start searching for query GB celebre Marmite disparait site supermarches Tesco cause Brexit
# Thu Oct 13 09:57:11 +0000 2016 786506059355652097
# Over: attempts:  1 remaining:  178
# key : 0
# Start searching for query Trump York
# Fri Oct 14 04:42:35 +0000 2016 786789274670608385
# Thu Oct 13 16:00:35 +0000 2016 786597510978609152
# Thu Oct 13 09:27:30 +0000 2016 786498586817232896
# Thu Oct 13 07:08:47 +0000 2016 786463680544251904
# Thu Oct 13 05:38:12 +0000 2016 786440884225277952
# Thu Oct 13 03:56:26 +0000 2016 786415272877928448
# Thu Oct 13 02:11:32 +0000 2016 786388872192077824
# Over: attempts:  7 remaining:  171
# Start searching for query USA campagne Trump dement accusations attouchements sexuels publiees New York Times
# Thu Oct 13 00:01:31 +0000 2016 786356152397361152
# Over: attempts:  1 remaining:  170
# key : 0
# ...

# %%
import os
print(len(os.listdir('/home/bmazoyer/Documents/TwitterSea/Filter')))
# Out:
# 23063
